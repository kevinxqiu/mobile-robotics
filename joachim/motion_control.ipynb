# %%
import os
import sys
import time
import serial

# Adding the src folder in the current directory as it contains the script
# with the Thymio class
#sys.path.insert(0, os.path.join(os.getcwd(), 'src'))

from Thymio import Thymio

# %%
class robot():
    def __init__(self):
        self.p_th = [0,0,0]
    def GetPosition(self):
        return self.p_th
    def SetPosition(self, p_tg):
        #distance
        d = math.sqrt( ((self.p_th[0]-p_tg[0])**2)+((self.p_th[1]-p_tg[1])**2))
        #angle
        alpha = math.arcos((p_tg[1]-self.p_th[1])/d) #angle to go to x,y
        new_theta = self.p_th[3] + alpha 
        if new_theta > 2*math.pi: new_theta -= 2*math.pi

        self.Angle(alpha)
        self.Distance(d)

        #update position and angle of the robot
        self.p_th = [p_tg[0],p_tg[1],new_theta]

    def Angle(self,new_theta):
        
    def Distance(self, d):

# %%
def Main():
    th = Thymio.serial(port="/dev/ttyACM0", refreshing_rate=0.1)
    th_m = robot()

# %%
dir(th)
# Out:
# ['GetPosition',
#  'SetPosition',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'auto_handshake',
#  'close',
#  'get_node_description',
#  'get_target_node_id',
#  'get_target_node_var_total_size',
#  'get_var',
#  'get_var_array',
#  'get_variables',
#  'handle_message',
#  'handshake',
#  'input_lock',
#  'input_thread',
#  'io',
#  'list_nodes',
#  'method',
#  'node_id',
#  'null',
#  'output_lock',
#  'refresh_thread',
#  'refreshing_timeout',
#  'refreshing_trigger',
#  'remote_node',
#  'send',
#  'serial',
#  'serial_default_port',
#  'set_refreshing_rate',
#  'set_var',
#  'set_var_array',
#  'set_variables',
#  'tcp',
#  'terminating',
#  'variable_description']

# %%
import types
import math 

def patch_me(target):
    def GetPosition(target):
        a=1
        return a
    def SetPosition(target, x, y, theta):
        x=1
    target.GetPosition = types.MethodType(GetPosition,target)
    target.SetPosition = types.MethodType(SetPosition,target)

#ls /dev/ttyACM*
#sudo chmod 666 /dev/ttyACM0
th = Thymio.serial(port="/dev/ttyACM0", refreshing_rate=0.1)
patch_me(th) #patch instance to add methods to Thymio class

a = th.GetPosition()
print(a)
th.SetPosition(0,2)
# Out:
# 1
# 0 2
# Message id=ID 14350 src=36869
# Message id=ID 10933 src=47
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=3584
# Message id=ID 33322 src=46848
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 1792 src=0
# Message id=ID 45571 src=45824
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 3584 src=0
# Message id=ID 45824 src=2048
# Message id=ID 46391 src=2852
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 948 src=5
# Message id=ID 702 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 0 src=0
# Message id=ID 8 src=0
# Message id=ID 0 src=0
# Exception in thread Exception in thread Exception in thread Thread-25Thread-5:
# :
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 537, in write
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 537, in write
# Thread-29:
# Traceback (most recent call last):
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 537, in write
#     n = os.write(self.fd, d)
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         n = os.write(self.fd, d)
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# n = os.write(self.fd, d)
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         self.run()self.run()
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 340, in do_refresh
#     self.get_variables()
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 499, in get_variables
#     self.send(msg)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 456, in send
#     self.io.write(msg.serialize())
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 571, in write
#     raise SerialException('write failed: {}'.format(e))
# serial.serialutil.SerialException: write failed: [Errno 5] Input/output error
#
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 340, in do_refresh
#     self.get_variables()
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 499, in get_variables
#     self.send(msg)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 456, in send
#     self.io.write(msg.serialize())
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 571, in write
#     raise SerialException('write failed: {}'.format(e))
# serial.serialutil.SerialException: write failed: [Errno 5] Input/output error
#     self._target(*self._args, **self._kwargs)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 340, in do_refresh
#     self.get_variables()
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 499, in get_variables
#     self.send(msg)
#   File "/home/yorm/OneDrive/MICRO-452 Basics of mobile robotics/Basics of mobile robotics - code/Project/Thymio.py", line 456, in send
#     self.io.write(msg.serialize())
#   File "/home/yorm/miniconda3/envs/mobileRobot/lib/python3.8/site-packages/serial/serialposix.py", line 571, in write
#     raise SerialException('write failed: {}'.format(e))
# serial.serialutil.SerialException: write failed: [Errno 5] Input/output error
